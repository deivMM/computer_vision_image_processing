# %%
import cv2
import os
import matplotlib.pyplot as plt
import numpy as np
import useful_functions as uf
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

from joblib import dump

# %%
df = pd.read_csv('data_entrenamiento.csv')

# Convertir 'id' a valores numéricos
label_encoder = LabelEncoder()
df["id"] = label_encoder.fit_transform(df["id"])
df
# Out:
#      id   h    s    v  hue_values  radio
# 0     0  14  126   89           0     30
# 1     0  15  147   87           1     31
# 2     0  15   90  113           1     31
# 3     0  17   99   93           1     33
# 4     0  15  114   92           1     30
# ..   ..  ..  ...  ...         ...    ...
# 447   5  19   50  162           2     40
# 448   5  21   47  113           2     38
# 449   5  17   45  175           3     39
# 450   5  20   46  165           4     41
# 451   5  20   48  133           3     39
#
# [452 rows x 6 columns]

# %%
# Separar features y target
X = df[['h','s','v','hue_values','radio']]
y = df["id"]

# Dividir en conjunto de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# Inicializar y entrenar modelo
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Predicciones
y_pred = model.predict(X_test)

# Evaluación
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred, target_names=label_encoder.classes_))

dump(model, 'modelo_random_forest.joblib')
# Out:
# Accuracy: 0.994475138121547
#               precision    recall  f1-score   support
#
#       tr_005       1.00      0.97      0.98        31
#        tr_01       0.97      1.00      0.99        36
#        tr_02       1.00      1.00      1.00        26
#        tr_05       1.00      1.00      1.00        21
#         tr_1       1.00      1.00      1.00        35
#         tr_2       1.00      1.00      1.00        32
#
#     accuracy                           0.99       181
#    macro avg       1.00      0.99      0.99       181
# weighted avg       0.99      0.99      0.99       181
# ['modelo_random_forest.joblib']
